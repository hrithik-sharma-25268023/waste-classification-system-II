# %% [markdown]
# tiny model 96x96x3

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# Set legacy Keras mode BEFORE any TensorFlow/Keras imports
os.environ["TF_USE_LEGACY_KERAS"] = "1"

import tensorflow as tf
import tf_keras as keras  # Use tf_keras for TFMOT compatibility
from tf_keras import layers
from tf_keras.preprocessing.image import ImageDataGenerator
import tensorflow_model_optimization as tfmot
import tensorflow.lite as tflite

from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

print("TF version:", tf.__version__)
print("GPUs:", tf.config.list_physical_devices("GPU"))
print("CPUs:", tf.config.list_physical_devices("CPU"))
# Out:
# WARNING:tensorflow:From C:\Users\Asghar\anaconda3\envs\waste_env\lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# TF version: 2.16.1
# GPUs: []
# CPUs: [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]

# %%
DATASET_PATH = "D:/waste_project/waste-classification-system-II/resized_dataset"

img_size = (96, 96)
batch_size = 32

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    DATASET_PATH,
    validation_split=0.2,
    subset="training",
    seed=42,
    image_size=img_size,
    batch_size=batch_size,
    color_mode="rgb"
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    DATASET_PATH,
    validation_split=0.2,
    subset="validation",
    seed=42,
    image_size=img_size,
    batch_size=batch_size,
    color_mode="rgb"
)

class_names = train_ds.class_names
num_classes = len(class_names)

AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.shuffle(1000).prefetch(AUTOTUNE)
val_ds = val_ds.prefetch(AUTOTUNE)

print("Classes:", class_names)
print("Number of classes:", num_classes)
# Out:
# Found 8407 files belonging to 9 classes.
# Using 6726 files for training.
# Found 8407 files belonging to 9 classes.
# Using 1681 files for validation.
# Classes: ['cardboard', 'e-waste', 'glass', 'metal', 'organic', 'paper', 'plastic', 'textile', 'trash']
# Number of classes: 9

# %%
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
])

train_ds = train_ds.map(
    lambda x, y: (data_augmentation(x, training=True), y)
)
# Out:
# WARNING:tensorflow:From C:\Users\Asghar\anaconda3\envs\waste_env\lib\site-packages\tf_keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
from tensorflow import keras
from tensorflow.keras import layers, models

num_classes = 9

def tiny_cnn_96x96_rgb():
    inputs = keras.Input(shape=(96, 96, 3))
    x = layers.Rescaling(1./255)(inputs)

    # Block 1
    x = layers.SeparableConv2D(32, 3, padding="same", activation="relu")(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D()(x)

    # Block 2
    x = layers.SeparableConv2D(64, 3, padding="same", activation="relu")(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D()(x)

    # Block 3
    x = layers.SeparableConv2D(96, 3, padding="same", activation="relu")(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D()(x)

    # Block 4 (small but helpful)
    x = layers.SeparableConv2D(128, 3, padding="same", activation="relu")(x)
    x = layers.BatchNormalization()(x)

    # Tiny head
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.3)(x)
    x = layers.Dense(48, activation="relu")(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)

    return keras.Model(inputs, outputs)

model = tiny_cnn_96x96_rgb()

model.compile(
    optimizer=keras.optimizers.Adam(1e-3),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\Asghar\anaconda3\envs\waste_env\lib\site-packages\tf_keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 96, 96, 3)]       0
#
#  rescaling (Rescaling)       (None, 96, 96, 3)         0
#
#  separable_conv2d (Separabl  (None, 96, 96, 32)        155
#  eConv2D)
#
#  batch_normalization (Batch  (None, 96, 96, 32)        128
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 48, 48, 32)        0
#  D)
#
#  separable_conv2d_1 (Separa  (None, 48, 48, 64)        2400
#  bleConv2D)
#
#  batch_normalization_1 (Bat  (None, 48, 48, 64)        256
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 24, 24, 64)        0
#  g2D)
#
#  separable_conv2d_2 (Separa  (None, 24, 24, 96)        6816
#  bleConv2D)
#
#  batch_normalization_2 (Bat  (None, 24, 24, 96)        384
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 12, 12, 96)        0
#  g2D)
#
#  separable_conv2d_3 (Separa  (None, 12, 12, 128)       13280
#  bleConv2D)
#
#  batch_normalization_3 (Bat  (None, 12, 12, 128)       512
#  chNormalization)
#
#  global_average_pooling2d (  (None, 128)               0
#  GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense (Dense)               (None, 48)                6192
#
#  dense_1 (Dense)             (None, 9)                 441
#
# =================================================================
# Total params: 30564 (119.39 KB)
# Trainable params: 29924 (116.89 KB)
# Non-trainable params: 640 (2.50 KB)
# _________________________________________________________________

# %%
es = keras.callbacks.EarlyStopping(
    monitor="val_loss",
    patience=6,
    restore_best_weights=True
)

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=40,
    callbacks=[es]
)
# Out:
# Epoch 1/40
# WARNING:tensorflow:From C:\Users\Asghar\anaconda3\envs\waste_env\lib\site-packages\tensorflow\python\autograph\converters\directives.py:126: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\
# Epoch 21/40
# 211/211 [==============================] - 49s 225ms/step - loss: 1.0838 - accuracy: 0.6183 - val_loss: 1.2635 - val_accuracy: 0.5556
# Epoch 22/40
# 211/211 [==============================] - 49s 221ms/step - loss: 1.0783 - accuracy: 0.6218 - val_loss: 1.2397 - val_accuracy: 0.5776
# Epoch 23/40
# 211/211 [==============================] - 54s 245ms/step - loss: 1.0537 - accuracy: 0.6323 - val_loss: 1.4864 - val_accuracy: 0.4902

# %%
import tensorflow_model_optimization as tfmot

prune_low_magnitude = tfmot.sparsity.keras.prune_low_magnitude

def prune_dense(layer):
    if isinstance(layer, keras.layers.Dense):
        return prune_low_magnitude(
            layer,
            pruning_schedule=tfmot.sparsity.keras.PolynomialDecay(
                initial_sparsity=0.0,
                final_sparsity=0.5,
                begin_step=0,
                end_step=1000
            )
        )
    return layer

pruned_model = keras.models.clone_model(model, clone_function=prune_dense)

pruned_model.compile(
    optimizer=keras.optimizers.Adam(5e-4),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

callbacks = [tfmot.sparsity.keras.UpdatePruningStep()]

pruned_model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=10,
    callbacks=callbacks
)
# Out:
# Epoch 1/10
# 211/211 [==============================] - 54s 210ms/step - loss: 1.0811 - accuracy: 0.6201 - val_loss: 1.1430 - val_accuracy: 0.6002
# Epoch 2/10
# 211/211 [==============================] - 46s 208ms/step - loss: 1.0785 - accuracy: 0.6228 - val_loss: 1.1687 - val_accuracy: 0.5919
# Epoch 3/10
# 211/211 [==============================] - 45s 205ms/step - loss: 1.0907 - accuracy: 0.6194 - val_loss: 1.1243 - val_accuracy: 0.6211
# Epoch 4/10
# 211/211 [==============================] - 49s 222ms/step - loss: 1.0730 - accuracy: 0.6262 - val_loss: 1.1427 - val_accuracy: 0.6044
# Epoch 5/10
# 211/211 [==============================] - 46s 210ms/step - loss: 1.0681 - accuracy: 0.6240 - val_loss: 1.1784 - val_accuracy: 0.5889
# Epoch 6/10
# 211/211 [==============================] - 46s 210ms/step - loss: 1.0585 - accuracy: 0.6271 - val_loss: 1.1103 - val_accuracy: 0.6169
# Epoch 7/10
# 211/211 [==============================] - 46s 207ms/step - loss: 1.0534 - accuracy: 0.6331 - val_loss: 1.1056 - val_accuracy: 0.6228
# Epoch 8/10
# 211/211 [==============================] - 46s 209ms/step - loss: 1.0432 - accuracy: 0.6375 - val_loss: 1.1117 - val_accuracy: 0.6175
# Epoch 9/10
# 211/211 [==============================] - 45s 206ms/step - loss: 1.0321 - accuracy: 0.6430 - val_loss: 1.4298 - val_accuracy: 0.5170
# Epoch 10/10
# 211/211 [==============================] - 47s 216ms/step - loss: 1.0283 - accuracy: 0.6402 - val_loss: 1.0750 - val_accuracy: 0.6377

# %%
model_for_export = tfmot.sparsity.keras.strip_pruning(pruned_model)

# %%
def representative_data_gen():
    for images, _ in train_ds.take(100):
        yield [tf.cast(images, tf.float32)]

converter = tf.lite.TFLiteConverter.from_keras_model(model_for_export)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.representative_dataset = representative_data_gen
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.int8
converter.inference_output_type = tf.int8

tflite_model = converter.convert()

with open("tiny_cnn_96x96_rgb_int8.tflite", "wb") as f:
    f.write(tflite_model)

print("INT8 size (KB):", len(tflite_model) / 1024)
# Out:
# INFO:tensorflow:Assets written to: C:\Users\Asghar\AppData\Local\Temp\tmp643pa5q1\assets
# INFO:tensorflow:Assets written to: C:\Users\Asghar\AppData\Local\Temp\tmp643pa5q1\assets
# C:\Users\Asghar\anaconda3\envs\waste_env\lib\site-packages\tensorflow\lite\python\convert.py:964: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# INT8 size (KB): 52.671875
